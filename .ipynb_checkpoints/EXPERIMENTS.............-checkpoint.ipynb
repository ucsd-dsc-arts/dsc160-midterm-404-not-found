# %%
from bs4 import BeautifulSoup
import os
import requests

# %%
## set up directories
DATA_DIR = '../data/'

## for Henri-matisse
HENRI_ARTIST_URL = 'http://www.henri-matisse.net/paintingssection{section_num}.html'
HENRI_PAINTING_URL = 'http://www.henri-matisse.net/{painting_source}'

## for Pablo Picasso
PABLO_URL = 'https://www.pablo-ruiz-picasso.net/{where_to_scrape}.php'
PABLO_PAINTING_URL = 'https://www.pablo-ruiz-picasso.net/{painting_source}'

## checking if our data directory is there or not
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

# %%
# getting all of the image urls
def scrape_arts_henri(sec_num):
    url_query = HENRI_ARTIST_URL.format(section_num=sec_num)
    artist_page = requests.get(url_query)

    # check for request error
    try:
        artist_page.raise_for_status()
    except requests.exceptions.HTTPError as e:
        print("Error trying to retrieve {}".format(artist_page.url))
        raise e

        
    soup = BeautifulSoup(artist_page.text, 'lxml')

    painting_paths = []
    ## filtering part, getting year between 1900-1942
    for li in soup.find_all('div', {'class': 'thmbnlspaintingselectbis'}):
        try:
            year = li.find('p').getText().split('\n')[-1].strip()
        except:
            year = li.getText().split('\n')[-1].strip()
        year_lst = year.split('-')
        year = year_lst[-1]
        if len(year) == 4:
            try:
                year = int(year)
            except:
                year = ''
        else:
            continue
        if(1900<=year<=1942):
            painting_paths.append(li.find('img').get('src'))
    return painting_paths

# %%
HENRI_ARTS = [scrape_arts_henri(sec_num) for sec_num in ['one', 'two', 'three']]
HENRI_ARTS = sum(HENRI_ARTS, [])
HENRI_ARTS
# Out:
# ['paintings/thmbnls150/bb.jpg',
#  'paintings/thmbnls150/ar.jpg',
#  'paintings/thmbnls150/ba.jpg',
#  'paintings/orient_99_thmb.jpg',
#  'paintings/thmbnls150/glimpse.jpg',
#  'paintings/thmbnls150/bd.jpg',
#  'paintings/thmbnls150/bc.jpg',
#  'paintings/thmbnls150/bh.jpg',
#  'paintings/thmbnls150/cs.jpg',
#  'paintings/orient_107_thmb.jpg',
#  'paintings/thmbnls150/bj.jpg',
#  'paintings/thmbnls150/dr.jpg',
#  'paintings/thmbnls150/bg.jpg',
#  'paintings/thmbnls150/bf.jpg',
#  'paintings/thmbnls150/zd.jpg',
#  'paintings/thmbnls150/bi.jpg',
#  'paintings/thmbnls150/hma308.jpg',
#  'paintings/thmbnls150/zq.jpg',
#  'paintings/thmbnls150/by.jpg',
#  'paintings/orient_109_thmb.jpg',
#  'paintings/orient_108_thmb.jpg',
#  'paintings/thmbnls150/gk.jpg',
#  'paintings/thmbnls150/zc.jpg',
#  'paintings/thmbnls150/zb.jpg',
#  'paintings/thmbnls150/ds.jpg',
#  'paintings/orient_113_thmb.jpg',
#  'paintings/thmbnls150/self.jpg',
#  'paintings/orient_111_thmb.jpg',
#  'paintings/thmbnls150/bu.jpg',
#  'paintings/thmbnls150/du.jpg',
#  'paintings/thmbnls150/hma313.jpg',
#  'paintings/orient_118_thmb.jpg',
#  'paintings/thmbnls150/dt.jpg',
#  'paintings/thmbnls150/ab.jpg',
#  'paintings/thmbnls150/aa.jpg',
#  'paintings/orient_127_thmb.jpg',
#  'paintings/thmbnls150/dv.jpg',
#  'paintings/thmbnls150/dx.jpg',
#  'paintings/orient_123_thmb.jpg',
#  'paintings/thmbnls150/cb.jpg',
#  'paintings/orient_129_thmb.jpg',
#  'paintings/thmbnls150//aq.jpg',
#  'paintings/thmbnls150/goldfish.jpg',
#  'paintings/thmbnls150/stilllifea_sm.jpg',
#  'paintings/thmbnls150/ac.jpg',
#  'paintings/thmbnls150/bv.jpg',
#  'paintings/thmbnls150/stilllifeb_sm.jpg',
#  'paintings/thmbnls150/eb.jpg',
#  'paintings/orient_47_thmb.jpg',
#  'paintings/thmbnls150/ea.jpg',
#  'paintings/thmbnls150/hma322.jpg',
#  'paintings/orient_159_thmb.jpg',
#  'paintings/thmbnls150/ec.jpg',
#  'paintings/thmbnls150/dy.jpg',
#  'paintings/orient_139_thmb.jpg',
#  'paintings/thmbnls150/ch.jpg',
#  'paintings/orient_143_thmb.jpg',
#  'paintings/thmbnls150/ed.jpg',
#  'paintings/orient_55_thmb.jpg',
#  'paintings/orient_145_thmb.jpg',
#  'paintings/thmbnls150/ee.jpg',
#  'paintings/orient_59_thmb.jpg',
#  'paintings/orient_141_thmb.jpg',
#  'paintings/thmbnls150/ad.jpg',
#  'paintings/thmbnls150/en.jpg',
#  'paintings/orient_179_thmb.jpg',
#  'paintings/thmbnls150/el.jpg',
#  'paintings/thmbnls150/eg.jpg',
#  'paintings/thmbnls150/hma96.jpg',
#  'paintings/thmbnls150/cc.jpg',
#  'paintings/thmbnls150/ei.jpg',
#  'paintings/thmbnls150/pntng43sm.jpg',
#  'paintings/orient_150_thmb.jpg',
#  'paintings/thmbnls150/zx.jpg',
#  'paintings/thmbnls150/gj.jpg',
#  'paintings/thmbnls150/q_84.jpg',
#  'paintings/orient_177_thmb.jpg',
#  'paintings/thmbnls150/cd.jpg',
#  'paintings/thmbnls150/q_85.jpg',
#  'paintings/thmbnls150/eq.jpg',
#  'paintings/thmbnls150/eo.jpg',
#  'paintings/thmbnls150/er.jpg',
#  'paintings/thmbnls150/eh.jpg',
#  'paintings/thmbnls150/ef.jpg',
#  'paintings/orient_187_thmb.jpg',
#  'paintings/thmbnls150/ep.jpg',
#  'paintings/thmbnls150/hma340.jpg',
#  'paintings/thmbnls150/gl.jpg',
#  'paintings/orient_189_thmb.jpg',
#  'paintings/thmbnls150/hma97.jpg',
#  'paintings/thmbnls150/zl.jpg',
#  'paintings/orient_185_thmb.jpg',
#  'paintings/thmbnls150/cj.jpg',
#  'paintings/thmbnls150/es.jpg',
#  'paintings/orient_186_thmb.jpg',
#  'paintings/thmbnls150/zn.jpg',
#  'paintings/thmbnls150/ce.jpg',
#  'paintings/thmbnls150/ev.jpg',
#  'paintings/thmbnls150/eu.jpg',
#  'paintings/orient_183_thmb.jpg',
#  'paintings/thmbnls150/et.jpg',
#  'paintings/thmbnls150/ew.jpg',
#  'paintings/thmbnls150/cf.jpg',
#  'paintings/thmbnls150/ex.jpg',
#  'paintings/thmbnls150/ez.jpg',
#  'paintings/thmbnls150/q_109.jpg',
#  'paintings/thmbnls150/fd.jpg',
#  'paintings/orient_193_thmb.jpg',
#  'paintings/orient_195_thmb.jpg',
#  'paintings/thmbnls150/ca.jpg',
#  'paintings/thmbnls150/fe.jpg',
#  'paintings/orient_191_thmb.jpg',
#  'paintings/orient_199_thmb.jpg',
#  'paintings/thmbnls150/ff.jpg',
#  'paintings/orient_84_thmb.jpg',
#  'paintings/orient_197_thmb.jpg',
#  'paintings/thmbnls150/fh.jpg',
#  'paintings/thmbnls150/fi.jpg',
#  'paintings/thmbnls150/q_133.jpg',
#  'paintings/thmbnls150/go.jpg',
#  'paintings/orient_211_thmb.jpg',
#  'paintings/thmbnls150/ey.jpg',
#  'paintings/thmbnls150/fk.jpg',
#  'paintings/thmbnls150/fl.jpg',
#  'paintings/thmbnls150/fo.jpg',
#  'paintings/thmbnls150/fj.jpg',
#  'paintings/thmbnls150/fm.jpg',
#  'paintings/thmbnls150/fp.jpg',
#  'paintings/thmbnls150/zp.jpg',
#  'paintings/thmbnls150/bz.jpg',
#  'paintings/orient_213_thmb.jpg',
#  'paintings/thmbnls150/de.jpg',
#  'paintings/thmbnls150/fr.jpg',
#  'paintings/thmbnls150/fq.jpg',
#  'paintings/thmbnls150/q_152.jpg',
#  'paintings/thmbnls150/fu.jpg',
#  'paintings/thmbnls150/ft.jpg',
#  'paintings/thmbnls150/fs.jpg',
#  'paintings/orient_214_thmb.jpg',
#  'paintings/thmbnls150/fw.jpg',
#  'paintings/thmbnls150/ga.jpg',
#  'paintings/thmbnls150/dc.jpg',
#  'paintings/thmbnls150/gb.jpg',
#  'paintings/thmbnls150/dd.jpg',
#  'paintings/thmbnls150/de.jpg',
#  'paintings/thmbnls150/dg.jpg',
#  'paintings/thmbnls150/gc.jpg',
#  'paintings/thmbnls150/gi.jpg',
#  'paintings/thmbnls150/df.jpg',
#  'paintings/thmbnls150/gd.jpg',
#  'paintings/thmbnls150/gn.jpg',
#  'paintings/thmbnls150/gm.jpg',
#  'paintings/thmbnls150/fz.jpg',
#  'paintings/select/gp.jpg',
#  'paintings/thmbnls150/dh.jpg']

# %%
# getting all of the image urls
def scrape_arts_pablo(here_to_scrape):
    PABLO_WEB = PABLO_URL.format(where_to_scrape=here_to_scrape)
    print(PABLO_WEB)
    artist_page = requests.get(PABLO_WEB)
    try:
        artist_page.raise_for_status()
    except requests.exceptions.HTTPError as e:
        print("Error trying to retrieve {}".format(artist_page.url))
        raise e

    soup = BeautifulSoup(artist_page.text, 'lxml')
    
    painting_paths = []
    pics = soup.find('div', {'id': 'main'}).find_all('div', style=lambda value: 'width' in value)
    
    ## filtering part, getting year between 1900-1942
    for pic in pics:
        year = pic.text.split(',')[-1].strip()
        year_lst = year.split('-')
        year = int(year_lst[-1])
        if (1900<=year<=1942):
            painting_paths.append(pic.find('img').get('src'))
    return painting_paths

# %%
PABLO_ARTS = scrape_arts_pablo('topviews')+scrape_arts_pablo('topshared')+scrape_arts_pablo('topexpensive')
PABLO_ARTS
# Out:
# https://www.pablo-ruiz-picasso.net/topviews.php
# https://www.pablo-ruiz-picasso.net/topshared.php
# https://www.pablo-ruiz-picasso.net/topexpensive.php
# ['images/works/57_s.jpg',
#  'images/works/2_s.jpg',
#  'images/works/117_s.jpg',
#  'images/works/3437_s.jpg',
#  'images/works/56_s.jpg',
#  'images/works/122_s.jpg',
#  'images/works/40_s.jpg',
#  'images/works/18_s.jpg',
#  'images/works/1513_s.jpg',
#  'images/works/3570_s.jpg',
#  'images/works/145_s.jpg',
#  'images/works/170_s.jpg',
#  'images/works/4000_s.jpg',
#  'images/works/1459_s.jpg',
#  'images/works/151_s.jpg',
#  'images/works/85_s.jpg',
#  'images/works/1885_s.jpg',
#  'images/works/3040_s.jpg',
#  'images/works/17_s.jpg',
#  'images/works/97_s.jpg',
#  'images/works/102_s.jpg',
#  'images/works/44_s.jpg',
#  'images/works/128_s.jpg',
#  'images/works/3501_s.jpg',
#  'images/works/1958_s.jpg',
#  'images/works/88_s.jpg',
#  'images/works/31_s.jpg',
#  'images/works/3960_s.jpg',
#  'images/works/61_s.jpg',
#  'images/works/263_s.jpg',
#  'images/works/3545_s.jpg',
#  'images/works/2033_s.jpg',
#  'images/works/158_s.jpg',
#  'images/works/1651_s.jpg',
#  'images/works/2025_s.jpg',
#  'images/works/35_s.jpg',
#  'images/works/3941_s.jpg',
#  'images/works/3461_s.jpg',
#  'images/works/2841_s.jpg',
#  'images/works/36_s.jpg',
#  'images/works/3447_s.jpg',
#  'images/works/174_s.jpg',
#  'images/works/1_s.jpg',
#  'images/works/6_s.jpg',
#  'images/works/1834_s.jpg',
#  'images/works/137_s.jpg',
#  'images/works/3197_s.jpg',
#  'images/works/93_s.jpg',
#  'images/works/148_s.jpg',
#  'images/works/4008_s.jpg',
#  'images/works/3351_s.jpg',
#  'images/works/14_s.jpg',
#  'images/works/108_s.jpg',
#  'images/works/173_s.jpg',
#  'images/works/183_s.jpg',
#  'images/works/3372_s.jpg',
#  'images/works/64_s.jpg',
#  'images/works/1663_s.jpg',
#  'images/works/73_s.jpg',
#  'images/works/1990_s.jpg',
#  'images/works/3934_s.jpg',
#  'images/works/1482_s.jpg',
#  'images/works/3451_s.jpg',
#  'images/works/3986_s.jpg',
#  'images/works/120_s.jpg',
#  'images/works/55_s.jpg',
#  'images/works/106_s.jpg',
#  'images/works/89_s.jpg',
#  'images/works/41_s.jpg',
#  'images/works/15_s.jpg',
#  'images/works/80_s.jpg',
#  'images/works/3944_s.jpg',
#  'images/works/62_s.jpg',
#  'images/works/1906_s.jpg',
#  'images/works/127_s.jpg',
#  'images/works/3984_s.jpg',
#  'images/works/1450_s.jpg',
#  'images/works/28_s.jpg',
#  'images/works/1941_s.jpg',
#  'images/works/3475_s.jpg',
#  'images/works/95_s.jpg',
#  'images/works/101_s.jpg',
#  'images/works/2142_s.jpg',
#  'images/works/3372_s.jpg',
#  'images/works/1878_s.jpg',
#  'images/works/1712_s.jpg',
#  'images/works/2553_s.jpg',
#  'images/works/3095_s.jpg',
#  'images/works/2033_s.jpg',
#  'images/works/1696_s.jpg',
#  'images/works/1482_s.jpg',
#  'images/works/1495_s.jpg',
#  'images/works/2647_s.jpg',
#  'images/works/2549_s.jpg',
#  'images/works/1982_s.jpg',
#  'images/works/1518_s.jpg',
#  'images/works/1525_s.jpg',
#  'images/works/1609_s.jpg',
#  'images/works/2479_s.jpg',
#  'images/works/2263_s.jpg',
#  'images/works/3301_s.jpg',
#  'images/works/1462_s.jpg',
#  'images/works/1575_s.jpg',
#  'images/works/262_s.jpg',
#  'images/works/2216_s.jpg',
#  'images/works/1742_s.jpg',
#  'images/works/1529_s.jpg',
#  'images/works/2595_s.jpg',
#  'images/works/2633_s.jpg',
#  'images/works/2078_s.jpg',
#  'images/works/2442_s.jpg',
#  'images/works/1563_s.jpg',
#  'images/works/2281_s.jpg',
#  'images/works/3421_s.jpg',
#  'images/works/64_s.jpg',
#  'images/works/1719_s.jpg',
#  'images/works/1731_s.jpg',
#  'images/works/1513_s.jpg',
#  'images/works/3378_s.jpg',
#  'images/works/2583_s.jpg',
#  'images/works/1528_s.jpg',
#  'images/works/2298_s.jpg',
#  'images/works/1929_s.jpg',
#  'images/works/1263_s.jpg',
#  'images/works/1233_s.jpg',
#  'images/works/2157_s.jpg',
#  'images/works/3113_s.jpg',
#  'images/works/2782_s.jpg',
#  'images/works/2587_s.jpg',
#  'images/works/51_s.jpg',
#  'images/works/2511_s.jpg',
#  'images/works/1991_s.jpg',
#  'images/works/2556_s.jpg',
#  'images/works/2324_s.jpg',
#  'images/works/1773_s.jpg',
#  'images/works/2173_s.jpg',
#  'images/works/2575_s.jpg',
#  'images/works/1651_s.jpg',
#  'images/works/137_s.jpg',
#  'images/works/2283_s.jpg',
#  'images/works/2083_s.jpg',
#  'images/works/2276_s.jpg',
#  'images/works/2589_s.jpg',
#  'images/works/1836_s.jpg',
#  'images/works/1736_s.jpg',
#  'images/works/2457_s.jpg',
#  'images/works/2450_s.jpg',
#  'images/works/2028_s.jpg',
#  'images/works/1471_s.jpg',
#  'images/works/1726_s.jpg',
#  'images/works/1613_s.jpg',
#  'images/works/1453_s.jpg',
#  'images/works/3219_s.jpg',
#  'images/works/2482_s.jpg',
#  'images/works/175_s.jpg',
#  'images/works/3337_s.jpg',
#  'images/works/3734_s.jpg',
#  'images/works/2154_s.jpg',
#  'images/works/1641_s.jpg',
#  'images/works/1550_s.jpg',
#  'images/works/1942_s.jpg',
#  'images/works/1562_s.jpg',
#  'images/works/125_s.jpg',
#  'images/works/1681_s.jpg',
#  'images/works/911_s.jpg',
#  'images/works/1687_s.jpg',
#  'images/works/2190_s.jpg',
#  'images/works/1722_s.jpg',
#  'images/works/1526_s.jpg',
#  'images/works/2166_s.jpg',
#  'images/works/3010_s.jpg',
#  'images/works/3545_s.jpg',
#  'images/works/2702_s.jpg',
#  'images/works/1483_s.jpg',
#  'images/works/2449_s.jpg',
#  'images/works/2654_s.jpg',
#  'images/works/2832_s.jpg',
#  'images/works/158_s.jpg',
#  'images/works/2310_s.jpg',
#  'images/works/3272_s.jpg',
#  'images/works/1706_s.jpg',
#  'images/works/1486_s.jpg',
#  'images/works/3297_s.jpg',
#  'images/works/1949_s.jpg',
#  'images/works/2112_s.jpg',
#  'images/works/2432_s.jpg',
#  'images/works/1755_s.jpg',
#  'images/works/1874_s.jpg',
#  'images/works/2890_s.jpg',
#  'images/works/840_s.jpg',
#  'images/works/33_s.jpg',
#  'images/works/3085_s.jpg',
#  'images/works/1107_s.jpg',
#  'images/works/1828_s.jpg',
#  'images/works/1670_s.jpg',
#  'images/works/2291_s.jpg',
#  'images/works/1718_s.jpg',
#  'images/works/2579_s.jpg',
#  'images/works/1543_s.jpg',
#  'images/works/1728_s.jpg',
#  'images/works/39_s.jpg',
#  'images/works/2655_s.jpg',
#  'images/works/3102_s.jpg',
#  'images/works/2187_s.jpg',
#  'images/works/1480_s.jpg',
#  'images/works/3001_s.jpg',
#  'images/works/2011_s.jpg',
#  'images/works/2991_s.jpg',
#  'images/works/2723_s.jpg',
#  'images/works/1936_s.jpg',
#  'images/works/1951_s.jpg',
#  'images/works/1792_s.jpg',
#  'images/works/3004_s.jpg',
#  'images/works/1535_s.jpg',
#  'images/works/1598_s.jpg',
#  'images/works/3941_s.jpg',
#  'images/works/3943_s.jpg',
#  'images/works/4055_s.jpg',
#  'images/works/3412_s.jpg',
#  'images/works/1621_s.jpg',
#  'images/works/4050_s.jpg',
#  'images/works/3040_s.jpg',
#  'images/works/3584_s.jpg',
#  'images/works/3944_s.jpg',
#  'images/works/2172_s.jpg',
#  'images/works/4053_s.jpg',
#  'images/works/3956_s.jpg',
#  'images/works/2142_s.jpg',
#  'images/works/4070_s.jpg',
#  'images/works/2244_s.jpg',
#  'images/works/2144_s.jpg',
#  'images/works/1760_s.jpg',
#  'images/works/3990_s.jpg',
#  'images/works/3634_s.jpg',
#  'images/works/1941_s.jpg',
#  'images/works/1970_s.jpg',
#  'images/works/2693_s.jpg',
#  'images/works/3377_s.jpg',
#  'images/works/1702_s.jpg',
#  'images/works/2230_s.jpg',
#  'images/works/2628_s.jpg',
#  'images/works/1845_s.jpg']

# %%
def download_and_save(artist_name):
    if artist_name == 'henri-matisse':
        painting_urls = HENRI_ARTS
        PAINTING_URL = HENRI_PAINTING_URL
    else:
        painting_urls = PABLO_ARTS
        PAINTING_URL = PABLO_PAINTING_URL
    
    IMAGE_DIR = os.path.join(DATA_DIR, artist_name)
    if not os.path.exists(IMAGE_DIR):
        os.makedirs(IMAGE_DIR)
    display(I)
    for url in painting_urls:
        download_url = PAINTING_URL.format(painting_source=url)
        outfile = os.path.join(IMAGE_DIR, url.replace('/','-'))
        if not os.path.exists(outfile):
            print("downloading: {}".format(url))
            r_painting_page = requests.get(download_url)
            with open(outfile, 'wb') as f:
                f.write(r_painting_page.content)
        else:
            pass

# %%
download_and_save('henri-matisse')
# Out:
# downloading: paintings/thmbnls150/bb.jpg
# downloading: paintings/thmbnls150/ar.jpg
# downloading: paintings/thmbnls150/ba.jpg
# downloading: paintings/orient_99_thmb.jpg
# downloading: paintings/thmbnls150/glimpse.jpg
# downloading: paintings/thmbnls150/bd.jpg
# downloading: paintings/thmbnls150/bc.jpg
# downloading: paintings/thmbnls150/bh.jpg
# downloading: paintings/thmbnls150/cs.jpg
# downloading: paintings/orient_107_thmb.jpg
# downloading: paintings/thmbnls150/bj.jpg
# downloading: paintings/thmbnls150/dr.jpg
# downloading: paintings/thmbnls150/bg.jpg
# downloading: paintings/thmbnls150/bf.jpg
# downloading: paintings/thmbnls150/zd.jpg
# downloading: paintings/thmbnls150/bi.jpg
# downloading: paintings/thmbnls150/hma308.jpg
# downloading: paintings/thmbnls150/zq.jpg
# downloading: paintings/thmbnls150/by.jpg
# downloading: paintings/orient_109_thmb.jpg
# downloading: paintings/orient_108_thmb.jpg
# downloading: paintings/thmbnls150/gk.jpg
# downloading: paintings/thmbnls150/zc.jpg
# downloading: paintings/thmbnls150/zb.jpg
# downloading: paintings/thmbnls150/ds.jpg
# downloading: paintings/orient_113_thmb.jpg
# downloading: paintings/thmbnls150/self.jpg
# downloading: paintings/orient_111_thmb.jpg
# downloading: paintings/thmbnls150/bu.jpg
# downloading: paintings/thmbnls150/du.jpg
# downloading: paintings/thmbnls150/hma313.jpg
# downloading: paintings/orient_118_thmb.jpg
# downloading: paintings/thmbnls150/dt.jpg
# downloading: paintings/thmbnls150/ab.jpg
# downloading: paintings/thmbnls150/aa.jpg
# downloading: paintings/orient_127_thmb.jpg
# downloading: paintings/thmbnls150/dv.jpg
# downloading: paintings/thmbnls150/dx.jpg
# downloading: paintings/orient_123_thmb.jpg
# downloading: paintings/thmbnls150/cb.jpg
# downloading: paintings/orient_129_thmb.jpg
# downloading: paintings/thmbnls150//aq.jpg
# downloading: paintings/thmbnls150/goldfish.jpg
# downloading: paintings/thmbnls150/stilllifea_sm.jpg
# downloading: paintings/thmbnls150/ac.jpg
# downloading: paintings/thmbnls150/bv.jpg
# downloading: paintings/thmbnls150/stilllifeb_sm.jpg
# downloading: paintings/thmbnls150/eb.jpg
# downloading: paintings/orient_47_thmb.jpg
# downloading: paintings/thmbnls150/ea.jpg
# downloading: paintings/thmbnls150/hma322.jpg
# downloading: paintings/orient_159_thmb.jpg
# downloading: paintings/thmbnls150/ec.jpg
# downloading: paintings/thmbnls150/dy.jpg
# downloading: paintings/orient_139_thmb.jpg
# downloading: paintings/thmbnls150/ch.jpg
# downloading: paintings/orient_143_thmb.jpg
# downloading: paintings/thmbnls150/ed.jpg
# downloading: paintings/orient_55_thmb.jpg
# downloading: paintings/orient_145_thmb.jpg
# downloading: paintings/thmbnls150/ee.jpg
# downloading: paintings/orient_59_thmb.jpg
# downloading: paintings/orient_141_thmb.jpg
# downloading: paintings/thmbnls150/ad.jpg
# downloading: paintings/thmbnls150/en.jpg
# downloading: paintings/orient_179_thmb.jpg
# downloading: paintings/thmbnls150/el.jpg
# downloading: paintings/thmbnls150/eg.jpg
# downloading: paintings/thmbnls150/hma96.jpg
# downloading: paintings/thmbnls150/cc.jpg
# downloading: paintings/thmbnls150/ei.jpg
# downloading: paintings/thmbnls150/pntng43sm.jpg
# downloading: paintings/orient_150_thmb.jpg

# %%
download_and_save('picasso')
